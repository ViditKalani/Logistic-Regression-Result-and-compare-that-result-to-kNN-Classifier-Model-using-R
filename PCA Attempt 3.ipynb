# %%
#Shoun Abraham

# %%
from sklearn.datasets import fetch_mldata
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("German_Credit.csv", index_col = 0)
df.head()
# Out:
#    Duration  Amount  InstallmentRatePercentage  ResidenceDuration  Age  \
# 1         6    1169                          4                  4   67
# 2        48    5951                          2                  2   22
# 3        12    2096                          2                  3   49
# 4        42    7882                          2                  4   45
# 5        24    4870                          3                  4   53
#
#    NumberExistingCredits  NumberPeopleMaintenance  Telephone  ForeignWorker  \
# 1                      2                        1          0              1
# 2                      1                        1          1              1
# 3                      1                        2          1              1
# 4                      1                        2          1              1
# 5                      2                        2          1              1
#
#   Class                   ...                    OtherInstallmentPlans.Bank  \
# ...

# %%
df['Class'].replace('Good', 1, inplace = True)
df['Class'].replace('Bad', 0, inplace = True)
df2 = df.drop(['Class'], axis = 1)
df2.head()
df3 = df[['Class']]
df3.head()
#df['Class']
# Out:
#    Class
# 1      1
# 2      0
# 3      1
# 4      1
# 5      0

# %%
pca = PCA(n_components=10)
pca.fit(df2)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=10, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
print(pca.components_)
# Out:
# [[  2.66997072e-03   9.99996415e-01  -1.07527079e-04   1.13105655e-05
#     1.31844373e-04   4.25541247e-06   2.19885531e-06  -4.81760508e-05
#     3.34868301e-06  -3.30584323e-06   1.87999446e-05  -8.65554951e-06
#    -6.83855189e-06   1.02233439e-05   4.53218008e-07  -1.53342436e-05
#     1.14020097e-05  -6.74432803e-06  -6.12161536e-06   2.71602929e-05
#    -4.64494085e-06  -2.75641958e-05  -2.67328301e-06  -1.50123528e-06
#    -5.70712690e-07  -0.00000000e+00  -2.33525545e-06   1.08065275e-05
#     7.44441804e-06  -6.31992459e-06   1.45941641e-06  -5.53351405e-06
#    -4.20827520e-06   1.46022974e-05  -6.88887634e-06  -6.21674662e-06
#     7.22328064e-06  -1.48214197e-06   7.36448429e-06   2.59701861e-06
#    -1.53243598e-05   2.68940671e-05  -1.41667260e-05  -0.00000000e+00
#    -4.23732873e-07   5.55764096e-06  -5.13390809e-06  -3.96073885e-05
#    -4.87083341e-06   1.26322295e-05   3.18459924e-05   4.84029566e-06
# ...

# %%
principle_components = pca.fit_transform(df)
print(principle_components)
# Out:
# [[ -2.10228622e+03   3.29313559e+01   3.36191910e+00 ...,  -1.66657420e-01
#    -2.65185482e-01   3.81196744e-01]
#  [  2.67980295e+03  -1.73197838e+01  -1.70543542e+01 ...,  -3.96524101e-01
#     4.66223791e-01   1.07648454e+00]
#  [ -1.17527574e+03   1.44408745e+01   3.26893198e+00 ...,   6.88417394e-01
#     6.71184293e-01   5.77162564e-01]
#  ...,
#  [ -2.46727275e+03   3.18453969e+00   1.71993191e+00 ...,   3.40091359e-01
#    -6.04152162e-01   4.98159216e-01]
#  [ -1.42619022e+03  -1.71493038e+01  -2.52660139e+01 ...,   8.49225069e-01
#    -6.77903152e-01   3.27453783e-01]
#  [  1.30480060e+03  -1.22590533e+01  -1.87116351e+01 ...,   2.77166651e-01
#     9.38666431e-02  -2.34913459e-01]]

# %%
df4 = pd.DataFrame(principle_components)
#df4.head()
df4.index = np.arange(1, len(df4) + 1)
df4.head()
df5 = df4.join(df3)
df5.head()
#pd.concat()
# Out:
#              0          1          2         3         4         5         6  \
# 1 -2102.286221  32.931356   3.361919 -0.657775 -0.876986  0.560159 -0.189341
# 2  2679.802949 -17.319784 -17.054354  1.179895  1.268521 -0.662220  0.024507
# 3 -1175.275741  14.440874   3.268932  0.562049  0.884034  0.656517  0.170322
# 4  4610.783164   7.124193 -10.215333 -0.580810  1.235284 -0.819677  0.287341
# 5  1598.746935  17.200115  -1.985796 -0.818432  0.166598 -0.259442  1.215347
#
#           7         8         9  Class
# 1 -0.166657 -0.265185  0.381197      1
# 2 -0.396524  0.466224  1.076485      0
# 3  0.688417  0.671184  0.577163      1
# 4  0.731074 -1.062652  0.667411      1
# 5  0.524174 -0.888239  0.443293      0

# %%
np.savetxt("temp_credit.csv", principle_components, delimiter=",")

# %%
df5.to_csv('pca_results.csv')
